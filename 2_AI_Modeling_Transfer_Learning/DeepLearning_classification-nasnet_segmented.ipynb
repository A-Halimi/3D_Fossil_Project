# %% [markdown]
# ##  Fossil-Classifier Transfer Learning nasnet

# %%
# %%time
# ============================================================================ 
#  Fossil-Classifier    (BBox Crop + MixUp/CutMix + Focal+LabelSmooth + EMA)
#  – Two-stage schedule (Freeze-10 ➜ Fine-Tune-20)   ·  EMA checkpoint
# ============================================================================

# ░░ 0 · Imports & reproducibility ░░
import os, warnings, random, json, math, datetime, pathlib, gc, numpy as np
import sys

os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
from absl import logging as absl_logging; absl_logging.set_verbosity(absl_logging.ERROR)
warnings.filterwarnings("ignore", category=UserWarning)

SEED = 42
random.seed(SEED); np.random.seed(SEED); os.environ["PYTHONHASHSEED"] = str(SEED)

import tensorflow as tf
tf.random.set_seed(SEED); tf.get_logger().setLevel("ERROR")
AUTOTUNE = tf.data.AUTOTUNE

def tf_beta_sample(alpha, shape, dtype=tf.float32):
    g1 = tf.random.gamma(shape, alpha, dtype=dtype)
    g2 = tf.random.gamma(shape, alpha, dtype=dtype)
    return g1 / (g1 + g2)

# Get the root directory of the project (Fossil_Project)
try:
    # Works in normal .py scripts
    PROJECT_ROOT = pathlib.Path(__file__).resolve().parent.parent
except NameError:
    # Fallback for Jupyter notebooks
    PROJECT_ROOT = pathlib.Path.cwd().parent

# ░░ 1 · User params ░░
DATA_ROOT = PROJECT_ROOT / "1_Dataset_Creation" / "3d_fossil_dataset_segmented_final"
SELECTED_MODEL         = "nasnet"          # pick any key from REGISTRY
BATCH_SIZE             = 32
FREEZE_EPOCHS          = 10
FINETUNE_EPOCHS        = 20

IMG_SIZE_SMALL         = (224,224)
IMG_SIZE_BIG           = (384,384)
UNFREEZE_MAP           = {
    "convnextl":120,"effv2l":80,"convnext":80,
    "effv2s":60,"nasnet":60,"resnet101v2":60,"mobilenet":999
}

# ░░ 2 · Output folders ░░
MODEL_DIR = PROJECT_ROOT / "3_Results" / SELECTED_MODEL
CKPT_DIR    = MODEL_DIR/"ckpts"
FIG_DIR     = MODEL_DIR/"figures"
REPORT_DIR  = MODEL_DIR/"reports"
for d in (CKPT_DIR, FIG_DIR, REPORT_DIR): d.mkdir(parents=True, exist_ok=True)

RUN_ID  = datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
LOG_DIR = MODEL_DIR/"logs"/f"{SELECTED_MODEL}_{RUN_ID}"; LOG_DIR.mkdir(parents=True, exist_ok=True)

# ░░ 3 · Backbone registry ░░
def _convnext_large():
    from tensorflow.keras.applications import ConvNeXtLarge, convnext
    return ConvNeXtLarge(weights="imagenet", include_top=False,
                         input_shape=(*IMG_SIZE_BIG,3)), convnext.preprocess_input, IMG_SIZE_BIG

def _convnext():
    from tensorflow.keras.applications import ConvNeXtBase, convnext
    return ConvNeXtBase(weights="imagenet", include_top=False,
                        input_shape=(*IMG_SIZE_SMALL,3)), convnext.preprocess_input, IMG_SIZE_SMALL

def _effv2s():
    from tensorflow.keras.applications import EfficientNetV2S, efficientnet_v2
    return EfficientNetV2S(weights="imagenet", include_top=False,
                           input_shape=(*IMG_SIZE_SMALL,3)), efficientnet_v2.preprocess_input, IMG_SIZE_SMALL

def _effv2l():
    from tensorflow.keras.applications import EfficientNetV2L, efficientnet_v2
    return EfficientNetV2L(weights="imagenet", include_top=False,
                           input_shape=(*IMG_SIZE_BIG,3)),  efficientnet_v2.preprocess_input, IMG_SIZE_BIG

def _nasnet():
    from tensorflow.keras.applications import NASNetLarge, nasnet
    return NASNetLarge(weights="imagenet", include_top=False,
                       input_shape=(331,331,3)), nasnet.preprocess_input, (331,331)

def _resnet101v2():
    from tensorflow.keras.applications import ResNet101V2, resnet_v2
    return ResNet101V2(weights="imagenet", include_top=False,
                       input_shape=(*IMG_SIZE_SMALL,3)), resnet_v2.preprocess_input, IMG_SIZE_SMALL

def _mobilenet():
    from tensorflow.keras.applications import MobileNet, mobilenet
    return MobileNet(weights="imagenet", include_top=False,
                     input_shape=(*IMG_SIZE_SMALL,3)), mobilenet.preprocess_input, IMG_SIZE_SMALL

REGISTRY = {
    "convnextl":_convnext_large,
    "convnext":_convnext,
    "effv2s":_effv2s,
    "effv2l":_effv2l,
    "nasnet":_nasnet,
    "resnet101v2":_resnet101v2,
    "mobilenet":_mobilenet
}

backbone, prep_fn, IMG_SIZE = REGISTRY[SELECTED_MODEL]()
print(f"Loaded {SELECTED_MODEL.upper()}  ·  input {IMG_SIZE}")

# ░░ 4 · Bounding-box crop helper (dtype-safe) ░░
@tf.autograph.experimental.do_not_convert
def crop_to_bbox(img):
    gray   = tf.image.rgb_to_grayscale(img)
    mask   = tf.where(gray > 0.05, 1, 0)
    coords = tf.cast(tf.where(tf.squeeze(mask)), tf.int32)

    y_min = tf.reduce_min(coords[:, 0]) - 5
    y_max = tf.reduce_max(coords[:, 0]) + 5
    x_min = tf.reduce_min(coords[:, 1]) - 5
    x_max = tf.reduce_max(coords[:, 1]) + 5

    h = tf.shape(img, out_type=tf.int32)[0]
    w = tf.shape(img, out_type=tf.int32)[1]

    y_min = tf.clip_by_value(y_min, 0, h)
    x_min = tf.clip_by_value(x_min, 0, w)
    y_max = tf.clip_by_value(y_max, 0, h)
    x_max = tf.clip_by_value(x_max, 0, w)

    crop = img[y_min:y_max, x_min:x_max]
    return tf.image.resize_with_pad(crop, *IMG_SIZE)

# ░░ 5 · Dataset with MixUp / CutMix ░░
@tf.autograph.experimental.do_not_convert
def _mixup_cutmix(images, labels, alpha=0.2, cutmix_prob=0.5):
    batch_sz = tf.shape(images)[0]
    lam = tf_beta_sample(alpha, [batch_sz, 1, 1, 1])           # [B,1,1,1]
    lam_flat = tf.reshape(lam, [batch_sz])                    # [B]
    idx = tf.random.shuffle(tf.range(batch_sz))
    img2, lab2 = tf.gather(images, idx), tf.gather(labels, idx)

    def do_cutmix():
        rx = tf.random.uniform([batch_sz], 0, IMG_SIZE[1], dtype=tf.float32)
        ry = tf.random.uniform([batch_sz], 0, IMG_SIZE[0], dtype=tf.float32)

        rw = IMG_SIZE[1] * tf.sqrt(1.0 - lam_flat)
        rh = IMG_SIZE[0] * tf.sqrt(1.0 - lam_flat)

        rw_int = tf.cast(rw, tf.int32)
        rh_int = tf.cast(rh, tf.int32)

        x1 = tf.cast(tf.clip_by_value(rx - 0.5 * tf.cast(rw_int, tf.float32), 0.0, float(IMG_SIZE[1])), tf.int32)
        y1 = tf.cast(tf.clip_by_value(ry - 0.5 * tf.cast(rh_int, tf.float32), 0.0, float(IMG_SIZE[0])), tf.int32)
        x2 = tf.clip_by_value(x1 + rw_int, 0, IMG_SIZE[1])
        y2 = tf.clip_by_value(y1 + rh_int, 0, IMG_SIZE[0])

        def make_mask(i):
            y1_i, y2_i = y1[i], y2[i]
            x1_i, x2_i = x1[i], x2[i]
            mask = tf.pad(
                tf.ones((y2_i - y1_i, x2_i - x1_i, 3), dtype=images.dtype),
                [[y1_i, IMG_SIZE[0] - y2_i], [x1_i, IMG_SIZE[1] - x2_i], [0, 0]]
            )
            return mask

        masks = tf.map_fn(make_mask, tf.range(batch_sz), dtype=images.dtype)  # [B,H,W,3]
        images_cut = images * (1 - masks) + img2 * masks

        area = tf.cast((x2 - x1) * (y2 - y1), tf.float32)  # [B]
        lam_scalar = 1.0 - area / (IMG_SIZE[0] * IMG_SIZE[1])  # [B]
        lam_scalar = tf.reshape(lam_scalar, [batch_sz, 1])  # [B,1]

        labels_cut = lam_scalar * labels + (1 - lam_scalar) * lab2
        return images_cut, labels_cut

    def do_mixup():
        images_mix = lam * images + (1 - lam) * img2
        lam_lbl = tf.reshape(lam_flat, [batch_sz, 1])
        labels_mix = lam_lbl * labels + (1 - lam_lbl) * lab2
        return images_mix, labels_mix

    rnd = tf.random.uniform([], 0.0, 1.0)
    images_out, labels_out = tf.cond(rnd < cutmix_prob, do_cutmix, do_mixup)
    return images_out, labels_out

def make_ds(split):
    base = tf.keras.utils.image_dataset_from_directory(
        DATA_ROOT/f"{split}", image_size=IMG_SIZE, batch_size=BATCH_SIZE,
        shuffle=(split=="train_split"), seed=SEED, label_mode="categorical")
    class_names = base.class_names

    ds = base
    ds = ds.map(lambda x,y: (tf.map_fn(crop_to_bbox, x), y), num_parallel_calls=AUTOTUNE)
    if split=="train_split":
        aug = tf.keras.Sequential([
            tf.keras.layers.RandomFlip("horizontal_and_vertical", seed=SEED),
            tf.keras.layers.RandomRotation(0.3, seed=SEED),
            tf.keras.layers.RandomContrast(0.3, seed=SEED),
            tf.keras.layers.RandomZoom(0.25, seed=SEED)])
        ds = ds.map(lambda x,y: (aug(x, training=True), y), num_parallel_calls=AUTOTUNE)
        ds = ds.map(lambda x,y: (prep_fn(x), y), num_parallel_calls=AUTOTUNE)
        ds = ds.map(_mixup_cutmix, num_parallel_calls=AUTOTUNE)
    else:
        ds = ds.map(lambda x,y: (prep_fn(x), y), num_parallel_calls=AUTOTUNE)
    return ds.prefetch(AUTOTUNE), class_names

train_ds, CLASS_NAMES = make_ds("train_split")
val_ds, _ = make_ds("val_split")
test_ds, _ = make_ds("test")
NUM_CLASSES = len(CLASS_NAMES)
(REPORT_DIR/f"class_map_{SELECTED_MODEL}.json").write_text(
    json.dumps({i:c for i,c in enumerate(CLASS_NAMES)}))

# ░░ 6 · Model head ░░
inputs = tf.keras.Input(shape=(*IMG_SIZE,3))
x = backbone(inputs, training=False)
x = tf.keras.layers.GlobalAveragePooling2D()(x)
x = tf.keras.layers.Dropout(0.5)(x)
outputs = tf.keras.layers.Dense(NUM_CLASSES, activation="softmax", dtype="float32")(x)
model = tf.keras.Model(inputs, outputs)

# ░░ 7 · Loss & metrics ░░
def focal_loss_with_label_smoothing(gamma=1.5, epsilon=0.05):
    def loss(y_true, y_pred):
        num_classes = tf.cast(tf.shape(y_true)[-1], tf.float32)
        y_true_sm = y_true * (1.0 - epsilon) + epsilon / num_classes
        y_pred_clipped = tf.clip_by_value(y_pred, 1e-7, 1.0)
        ce = - y_true_sm * tf.math.log(y_pred_clipped)  # [B, C]
        weight = tf.pow(1.0 - y_pred_clipped, gamma)    # [B, C]
        loss_tensor = weight * ce                       # [B, C]
        return tf.reduce_sum(loss_tensor, axis=-1)      # per-example
    return loss

loss_fn  = focal_loss_with_label_smoothing(gamma=1.5, epsilon=0.05)
metrics  = [
    tf.keras.metrics.CategoricalAccuracy(name="acc"),
    tf.keras.metrics.TopKCategoricalAccuracy(k=3, name="top3"),
    tf.keras.metrics.AUC(name="auc")
]

# ░░ EMA callback (replacement for StructuredEMA) ░░
class SimpleEMA(tf.keras.callbacks.Callback):
    def __init__(self, momentum=0.999):
        super().__init__()
        self.momentum = momentum
        self.ema_weights = None
        self.backup_weights = None
        self._model = None

    def set_model(self, model):
        self._model = model
        self.ema_weights = [tf.identity(w) for w in self._model.get_weights()]

    def on_batch_end(self, batch, logs=None):
        current = self._model.get_weights()
        self.ema_weights = [
            self.momentum * ew + (1.0 - self.momentum) * cw
            for ew, cw in zip(self.ema_weights, current)
        ]

    def on_test_begin(self, logs=None):
        if self._model is None:
            return
        self.backup_weights = self._model.get_weights()
        self._model.set_weights(self.ema_weights)

    def on_test_end(self, logs=None):
        if self._model is None or self.backup_weights is None:
            return
        self._model.set_weights(self.backup_weights)
        self.backup_weights = None

# ░░ 8 · Stage-1 (frozen) ░░
train_card = tf.data.experimental.cardinality(train_ds).numpy()
lr1 = tf.keras.optimizers.schedules.CosineDecay(3e-4, train_card * FREEZE_EPOCHS)
opt1 = tf.keras.optimizers.AdamW(lr1, weight_decay=5e-4)
model.compile(optimizer=opt1, loss=loss_fn, metrics=metrics)

tb_cb   = tf.keras.callbacks.TensorBoard(log_dir=str(LOG_DIR))
ema_cb  = SimpleEMA(momentum=0.999)
ckpt_cb = tf.keras.callbacks.ModelCheckpoint(
    CKPT_DIR/"best.keras", monitor="val_acc", save_best_only=True, verbose=1)
es_cb   = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss", patience=6, restore_best_weights=True, verbose=1)

print("\n—— Stage 1 (Frozen) ——")
hist1 = model.fit(
    train_ds, validation_data=val_ds, epochs=FREEZE_EPOCHS,
    callbacks=[tb_cb, ckpt_cb, es_cb, ema_cb]
)

# ░░ 9 · Stage-2 (top-N) ░░
backbone.trainable = True
N = UNFREEZE_MAP[SELECTED_MODEL]
for lyr in backbone.layers[:-N]:
    lyr.trainable = False

opt2 = tf.keras.optimizers.AdamW(1e-5, weight_decay=5e-4, clipnorm=1.0)
model.compile(optimizer=opt2, loss=loss_fn, metrics=metrics)

print("\n—— Stage 2 (Fine-Tune top-N) ——")
hist2 = model.fit(
    train_ds, validation_data=val_ds,
    epochs=FREEZE_EPOCHS + FINETUNE_EPOCHS, initial_epoch=FREEZE_EPOCHS,
    callbacks=[tb_cb, ckpt_cb, es_cb, ema_cb]
)

# ░░ 10 · Evaluation ░░
# load best checkpoint (non-EMA) for consistency, then evaluate with EMA weights separately
model = tf.keras.models.load_model(CKPT_DIR/"best.keras", compile=False)
model.compile(loss=loss_fn, metrics=metrics)
results = dict(zip(model.metrics_names, model.evaluate(test_ds, verbose=0)))
for k,v in results.items(): print(f"{k:>9s} : {v:.4f}")

# save standard best model
model.save(MODEL_DIR/f"fossil_{SELECTED_MODEL}.keras")

# save EMA-weighted model
# apply EMA weights from callback (if available)
if ema_cb.ema_weights is not None:
    original = model.get_weights()
    model.set_weights(ema_cb.ema_weights)
    model.save(MODEL_DIR/f"fossil_{SELECTED_MODEL}_ema.keras")
    model.set_weights(original)

# ░░ 11 · History merge & save ░░
def _merge(histories, key):
    out=[]
    for h in histories: out += h.history.get(key,[])
    return out

all_hist = {
    "loss":_merge([hist1,hist2],"loss"),
    "val_loss":_merge([hist1,hist2],"val_loss"),
    "acc":_merge([hist1,hist2],"acc"),
    "val_acc":_merge([hist1,hist2],"val_acc"),
    "auc":_merge([hist1,hist2],"auc"),
    "val_auc":_merge([hist1,hist2],"val_auc"),
    "top3":_merge([hist1,hist2],"top3"),
    "val_top3":_merge([hist1,hist2],"val_top3")
}
(REPORT_DIR/f"training_history_{SELECTED_MODEL}.json").write_text(json.dumps(all_hist, indent=4))

# ░░ 12 · Plots ░░
import matplotlib.pyplot as plt, seaborn as sns
plt.figure(figsize=(14,10)); plt.suptitle(f"Training History – {SELECTED_MODEL.upper()}", fontsize=16)
for i,(k,title) in enumerate([("loss","Loss"),("acc","Accuracy"),("auc","AUC"),("top3","Top-3 Accuracy")]):
    plt.subplot(2,2,i+1)
    plt.plot(all_hist[k], label="Train"); plt.plot(all_hist[f"val_{k}"], label="Val")
    plt.axvline(FREEZE_EPOCHS-1, linestyle="--", label="Fine-Tune Start")
    plt.title(title); plt.xlabel("Epoch"); plt.legend()
plt.tight_layout(rect=[0,0.03,1,0.95])
plt.savefig(FIG_DIR/f"history_{SELECTED_MODEL}.pdf", bbox_inches='tight')

# ░░ 13 · Classification report & confusion matrix ░░
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, accuracy_score, f1_score
probs  = model.predict(test_ds, verbose=0); y_pred = probs.argmax(1)
y_true_one_hot = np.concatenate([y for _,y in test_ds]); y_true = y_true_one_hot.argmax(1)
test_acc = accuracy_score(y_true,y_pred)
top3 = tf.keras.metrics.top_k_categorical_accuracy(y_true_one_hot, probs, k=3).numpy().mean()
auc  = roc_auc_score(y_true_one_hot, probs, multi_class="ovr")
macro_f1 = f1_score(y_true,y_pred,average="macro")
header = f"""
Overall Test Metrics
====================
Test Accuracy : {test_acc:.4f}
Top-3 Accuracy: {top3:.4f}
Test AUC      : {auc:.4f}
Macro-F1      : {macro_f1:.4f}

Classification Report
====================
"""
full_rep = header + classification_report(y_true, y_pred, target_names=CLASS_NAMES, digits=4)
(REPORT_DIR/f"classification_report_{SELECTED_MODEL}.txt").write_text(full_rep)
print(full_rep)

cm = confusion_matrix(y_true,y_pred)
plt.figure(figsize=(14,12))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=CLASS_NAMES, yticklabels=CLASS_NAMES)
plt.xticks(rotation=45, ha='right'); plt.yticks(rotation=0)
plt.title(f"Confusion Matrix – {SELECTED_MODEL.upper()}")
plt.savefig(FIG_DIR/f"cm_{SELECTED_MODEL}.pdf", dpi=300, bbox_inches='tight')
plt.show()

print("\n✅ All done - outputs saved in:", MODEL_DIR)
# Out:
# 2025-08-03 07:43:28.294159: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1754207008.320210     186 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1754207008.333146     186 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# I0000 00:00:1754207024.078844     186 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 79193 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-80GB, pci bus id: 0000:85:00.0, compute capability: 8.0
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/nasnet/NASNet-large-no-top.h5
# 343610240/343610240 ━━━━━━━━━━━━━━━━━━━━ 26s 0us/step
# Loaded NASNET  ·  input (331, 331)
# Found 44103 files belonging to 12 classes.
# WARNING: AutoGraph could not transform <function make_ds.<locals>.<lambda> at 0x7f011bf03d80> and will run it as-is.
# Cause: could not parse the source code of <function make_ds.<locals>.<lambda> at 0x7f011bf03d80>: no matching AST found among candidates:
#
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function make_ds.<locals>.<lambda> at 0x7f011bd48b80> and will run it as-is.
# Cause: could not parse the source code of <function make_ds.<locals>.<lambda> at 0x7f011bd48b80>: no matching AST found among candidates:
#
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function make_ds.<locals>.<lambda> at 0x7f011bf02e80> and will run it as-is.
# Cause: could not parse the source code of <function make_ds.<locals>.<lambda> at 0x7f011bf02e80>: no matching AST found among candidates:
#
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# Found 14046 files belonging to 12 classes.
# WARNING: AutoGraph could not transform <function make_ds.<locals>.<lambda> at 0x7f011ba0b420> and will run it as-is.
# Cause: could not parse the source code of <function make_ds.<locals>.<lambda> at 0x7f011ba0b420>: no matching AST found among candidates:
#
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function make_ds.<locals>.<lambda> at 0x7f011ba08d60> and will run it as-is.
# Cause: could not parse the source code of <function make_ds.<locals>.<lambda> at 0x7f011ba08d60>: no matching AST found among candidates:
#
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# Found 51468 files belonging to 12 classes.
# WARNING: AutoGraph could not transform <function make_ds.<locals>.<lambda> at 0x7f011bc07060> and will run it as-is.
# Cause: could not parse the source code of <function make_ds.<locals>.<lambda> at 0x7f011bc07060>: no matching AST found among candidates:
#
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function make_ds.<locals>.<lambda> at 0x7f011bc6bb00> and will run it as-is.
# Cause: could not parse the source code of <function make_ds.<locals>.<lambda> at 0x7f011bc6bb00>: no matching AST found among candidates:
#
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
#
# —— Stage 1 (Frozen) ——
# Epoch 1/10
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1754207313.225329     215 service.cc:148] XLA service 0x7f00d80044f0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1754207313.226190     215 service.cc:156]   StreamExecutor device (0): NVIDIA A100-SXM4-80GB, Compute Capability 8.0
# I0000 00:00:1754207339.432883     215 cuda_dnn.cc:529] Loaded cuDNN version 90700
# E0000 00:00:1754207356.001833     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754207356.230155     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754207356.516764     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754207356.671235     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754207357.707583     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754207357.916259     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754207358.561013     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754207358.732198     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754207359.443018     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754207359.608065     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754207360.162180     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754207360.319841     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754207361.103047     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754207361.257383     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754207361.877509     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754207362.032445     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754207363.198786     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754207363.364585     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754207363.828477     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754207363.982315     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754207364.353012     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754207364.518197     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754207364.889535     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754207365.043201     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754207365.414757     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754207365.568438     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754207366.895069     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754207367.060860     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754207367.323242     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754207367.478488     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754207367.887313     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754207368.053275     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754207368.503104     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754207368.668670     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754207368.888474     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754207369.038988     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754207369.431166     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754207369.597159     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754207369.852356     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754207370.002864     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754207370.389591     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754207370.555668     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754207371.799703     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754207371.954971     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754207372.447090     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754207372.612935     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754207373.649320     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754207373.809874     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754207373.974738     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754207374.135759     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754207374.499399     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754207374.676407     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754207374.864218     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754207375.823961     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754207375.991856     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754207377.419166     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754207377.587656     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754207378.669739     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754207378.837895     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754207379.447173     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754207379.615593     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754207381.446102     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754207381.686685     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754207383.401317     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754207383.641823     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754207386.336777     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754207386.521683     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754207397.242068     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754207397.397497     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754207398.037745     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754207398.188994     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754207398.686724     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754207398.838118     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# I0000 00:00:1754207449.743979     215 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1378/1379 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - acc: 0.7989 - auc: 0.8091 - loss: 0.7899 - top3: 0.9341
# E0000 00:00:1754209289.496282     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209289.695661     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209289.981092     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209290.130990     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209290.513037     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209290.697154     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209291.029674     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209291.189915     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209291.576859     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209291.734763     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209292.079481     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209292.231578     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209292.830268     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209292.980904     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209293.308018     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209293.458724     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209294.221258     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209294.380558     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209294.741823     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209294.893485     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209295.210555     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209295.369674     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209295.697686     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209295.850254     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209296.277597     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209296.429753     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209297.256138     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209297.417705     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209297.919069     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209298.073063     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209298.266103     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209298.426821     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209298.873285     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209299.034661     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209299.474532     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209299.622703     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209299.820873     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209299.977766     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209300.330281     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209300.480372     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209301.682849     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209301.833832     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209302.019777     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209302.180996     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209302.856026     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209303.014726     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209303.294069     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209303.470445     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209303.957856     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209304.117387     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209304.966146     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209305.129886     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209305.553343     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209305.711646     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209306.064961     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209306.224412     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209307.150083     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209307.380726     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209307.609313     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209308.490233     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209308.692774     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209309.079404     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209309.247289     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209314.488899     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209314.641209     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209315.122288     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209315.272443     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209315.750651     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209315.900466     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 1379/1379 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - acc: 0.7989 - auc: 0.8091 - loss: 0.7898 - top3: 0.9341
# E0000 00:00:1754209429.797328     217 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209430.025087     217 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209430.309365     217 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209430.463793     217 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209431.453358     217 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209431.661220     217 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209432.275457     217 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209432.446037     217 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209433.108957     217 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209433.274087     217 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209433.791067     217 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209433.948637     217 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209434.722260     217 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209434.876727     217 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209435.426707     217 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209435.581151     217 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209436.807880     217 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209436.973707     217 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209437.410048     217 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209437.563825     217 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209437.919405     217 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209438.085096     217 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209438.438299     217 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209438.592072     217 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209438.947691     217 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209439.101413     217 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209440.355984     217 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209440.521807     217 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209440.774400     217 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209440.929499     217 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209441.326191     217 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209441.492299     217 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209441.924671     217 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209442.090263     217 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209442.304048     217 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209442.454542     217 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209442.835025     217 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209443.001111     217 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209443.242857     217 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209443.393415     217 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209443.768467     217 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754209443.934714     217 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# Epoch 1: val_acc improved from -inf to 0.78691, saving model to results_stronger_regularization_v11_segmented_o3/nasnet/ckpts/best.keras
# 1379/1379 ━━━━━━━━━━━━━━━━━━━━ 2386s 1s/step - acc: 0.7989 - auc: 0.8091 - loss: 0.7897 - top3: 0.9341 - val_acc: 0.7869 - val_auc: 0.9571 - val_loss: 0.8695 - val_top3: 0.9209
# Epoch 2/10
# 1379/1379 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - acc: 0.8857 - auc: 0.8608 - loss: 0.5309 - top3: 0.9850
# Epoch 2: val_acc did not improve from 0.78691
# 1379/1379 ━━━━━━━━━━━━━━━━━━━━ 1695s 1s/step - acc: 0.8857 - auc: 0.8608 - loss: 0.5309 - top3: 0.9850 - val_acc: 0.7530 - val_auc: 0.9625 - val_loss: 0.8883 - val_top3: 0.9176
# Epoch 3/10
# 1379/1379 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - acc: 0.8969 - auc: 0.8785 - loss: 0.4821 - top3: 0.9894
# Epoch 3: val_acc did not improve from 0.78691
# 1379/1379 ━━━━━━━━━━━━━━━━━━━━ 1698s 1s/step - acc: 0.8969 - auc: 0.8785 - loss: 0.4821 - top3: 0.9894 - val_acc: 0.5667 - val_auc: 0.9311 - val_loss: 1.2837 - val_top3: 0.9053
# Epoch 4/10
# 1379/1379 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - acc: 0.9031 - auc: 0.8902 - loss: 0.4539 - top3: 0.9919
# Epoch 4: val_acc improved from 0.78691 to 0.80350, saving model to results_stronger_regularization_v11_segmented_o3/nasnet/ckpts/best.keras
# 1379/1379 ━━━━━━━━━━━━━━━━━━━━ 1678s 1s/step - acc: 0.9031 - auc: 0.8902 - loss: 0.4539 - top3: 0.9919 - val_acc: 0.8035 - val_auc: 0.9799 - val_loss: 0.6329 - val_top3: 0.9581
# Epoch 5/10
# 1379/1379 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - acc: 0.9168 - auc: 0.9052 - loss: 0.4191 - top3: 0.9936
# Epoch 5: val_acc improved from 0.80350 to 0.84999, saving model to results_stronger_regularization_v11_segmented_o3/nasnet/ckpts/best.keras
# 1379/1379 ━━━━━━━━━━━━━━━━━━━━ 1668s 1s/step - acc: 0.9168 - auc: 0.9052 - loss: 0.4191 - top3: 0.9936 - val_acc: 0.8500 - val_auc: 0.9799 - val_loss: 0.5754 - val_top3: 0.9466
# Epoch 6/10
# 1379/1379 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - acc: 0.9258 - auc: 0.9144 - loss: 0.4030 - top3: 0.9948
# Epoch 6: val_acc improved from 0.84999 to 0.88288, saving model to results_stronger_regularization_v11_segmented_o3/nasnet/ckpts/best.keras
# 1379/1379 ━━━━━━━━━━━━━━━━━━━━ 1680s 1s/step - acc: 0.9258 - auc: 0.9144 - loss: 0.4030 - top3: 0.9948 - val_acc: 0.8829 - val_auc: 0.9845 - val_loss: 0.5152 - val_top3: 0.9541
# Epoch 7/10
# 1379/1379 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - acc: 0.9352 - auc: 0.9234 - loss: 0.3810 - top3: 0.9970
# Epoch 7: val_acc improved from 0.88288 to 0.89349, saving model to results_stronger_regularization_v11_segmented_o3/nasnet/ckpts/best.keras
# 1379/1379 ━━━━━━━━━━━━━━━━━━━━ 1676s 1s/step - acc: 0.9352 - auc: 0.9234 - loss: 0.3810 - top3: 0.9970 - val_acc: 0.8935 - val_auc: 0.9877 - val_loss: 0.4724 - val_top3: 0.9745
# Epoch 8/10
# 1379/1379 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - acc: 0.9417 - auc: 0.9293 - loss: 0.3694 - top3: 0.9979
# Epoch 8: val_acc improved from 0.89349 to 0.90047, saving model to results_stronger_regularization_v11_segmented_o3/nasnet/ckpts/best.keras
# 1379/1379 ━━━━━━━━━━━━━━━━━━━━ 1710s 1s/step - acc: 0.9417 - auc: 0.9293 - loss: 0.3694 - top3: 0.9980 - val_acc: 0.9005 - val_auc: 0.9858 - val_loss: 0.4542 - val_top3: 0.9700
# Epoch 9/10
# 1379/1379 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - acc: 0.9471 - auc: 0.9344 - loss: 0.3604 - top3: 0.9985
# Epoch 9: val_acc improved from 0.90047 to 0.90332, saving model to results_stronger_regularization_v11_segmented_o3/nasnet/ckpts/best.keras
# 1379/1379 ━━━━━━━━━━━━━━━━━━━━ 1733s 1s/step - acc: 0.9471 - auc: 0.9344 - loss: 0.3604 - top3: 0.9985 - val_acc: 0.9033 - val_auc: 0.9845 - val_loss: 0.4384 - val_top3: 0.9737
# Epoch 10/10
# 1379/1379 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - acc: 0.9502 - auc: 0.9359 - loss: 0.3561 - top3: 0.9989
# Epoch 10: val_acc did not improve from 0.90332
# 1379/1379 ━━━━━━━━━━━━━━━━━━━━ 1686s 1s/step - acc: 0.9502 - auc: 0.9359 - loss: 0.3561 - top3: 0.9989 - val_acc: 0.9010 - val_auc: 0.9857 - val_loss: 0.4309 - val_top3: 0.9778
# Restoring model weights from the end of the best epoch: 10.
#
# —— Stage 2 (Fine-Tune top-N) ——
# Epoch 11/30
# 1379/1379 ━━━━━━━━━━━━━━━━━━━━ 0s 925ms/step - acc: 0.9280 - auc: 0.9473 - loss: 0.3548 - top3: 0.9895
# Epoch 11: val_acc did not improve from 0.90332
# 1379/1379 ━━━━━━━━━━━━━━━━━━━━ 1396s 970ms/step - acc: 0.9280 - auc: 0.9473 - loss: 0.3548 - top3: 0.9895 - val_acc: 0.9005 - val_auc: 0.9862 - val_loss: 0.4277 - val_top3: 0.9792
# Epoch 12/30
# 1379/1379 ━━━━━━━━━━━━━━━━━━━━ 0s 922ms/step - acc: 0.9508 - auc: 0.9336 - loss: 0.3570 - top3: 0.9987
# Epoch 12: val_acc did not improve from 0.90332
# 1379/1379 ━━━━━━━━━━━━━━━━━━━━ 1363s 952ms/step - acc: 0.9508 - auc: 0.9336 - loss: 0.3570 - top3: 0.9987 - val_acc: 0.9008 - val_auc: 0.9862 - val_loss: 0.4269 - val_top3: 0.9801
# Epoch 13/30
# 1379/1379 ━━━━━━━━━━━━━━━━━━━━ 0s 920ms/step - acc: 0.9511 - auc: 0.9350 - loss: 0.3552 - top3: 0.9987
# Epoch 13: val_acc did not improve from 0.90332
# 1379/1379 ━━━━━━━━━━━━━━━━━━━━ 1312s 951ms/step - acc: 0.9511 - auc: 0.9350 - loss: 0.3552 - top3: 0.9987 - val_acc: 0.9000 - val_auc: 0.9863 - val_loss: 0.4262 - val_top3: 0.9803
# Epoch 14/30
# 1379/1379 ━━━━━━━━━━━━━━━━━━━━ 0s 918ms/step - acc: 0.9534 - auc: 0.9351 - loss: 0.3548 - top3: 0.9987
# Epoch 14: val_acc did not improve from 0.90332
# 1379/1379 ━━━━━━━━━━━━━━━━━━━━ 1339s 948ms/step - acc: 0.9534 - auc: 0.9351 - loss: 0.3548 - top3: 0.9987 - val_acc: 0.9001 - val_auc: 0.9867 - val_loss: 0.4256 - val_top3: 0.9816
# Epoch 15/30
# 1379/1379 ━━━━━━━━━━━━━━━━━━━━ 0s 915ms/step - acc: 0.9523 - auc: 0.9348 - loss: 0.3559 - top3: 0.9989
# Epoch 15: val_acc did not improve from 0.90332
# 1379/1379 ━━━━━━━━━━━━━━━━━━━━ 1306s 946ms/step - acc: 0.9523 - auc: 0.9348 - loss: 0.3559 - top3: 0.9989 - val_acc: 0.9005 - val_auc: 0.9872 - val_loss: 0.4245 - val_top3: 0.9821
# Epoch 16/30
# 1379/1379 ━━━━━━━━━━━━━━━━━━━━ 0s 914ms/step - acc: 0.9528 - auc: 0.9351 - loss: 0.3544 - top3: 0.9994
# Epoch 16: val_acc did not improve from 0.90332
# 1379/1379 ━━━━━━━━━━━━━━━━━━━━ 1340s 944ms/step - acc: 0.9528 - auc: 0.9351 - loss: 0.3544 - top3: 0.9994 - val_acc: 0.9002 - val_auc: 0.9869 - val_loss: 0.4248 - val_top3: 0.9816
# Epoch 17/30
# 1379/1379 ━━━━━━━━━━━━━━━━━━━━ 0s 914ms/step - acc: 0.9521 - auc: 0.9362 - loss: 0.3543 - top3: 0.9991
# Epoch 17: val_acc did not improve from 0.90332
# 1379/1379 ━━━━━━━━━━━━━━━━━━━━ 1304s 944ms/step - acc: 0.9521 - auc: 0.9362 - loss: 0.3543 - top3: 0.9991 - val_acc: 0.9005 - val_auc: 0.9869 - val_loss: 0.4240 - val_top3: 0.9804
# Epoch 18/30
# 1379/1379 ━━━━━━━━━━━━━━━━━━━━ 0s 902ms/step - acc: 0.9542 - auc: 0.9359 - loss: 0.3540 - top3: 0.9990
# Epoch 18: val_acc did not improve from 0.90332
# 1379/1379 ━━━━━━━━━━━━━━━━━━━━ 1328s 962ms/step - acc: 0.9542 - auc: 0.9359 - loss: 0.3540 - top3: 0.9990 - val_acc: 0.9007 - val_auc: 0.9861 - val_loss: 0.4246 - val_top3: 0.9794
# Epoch 19/30
# 1379/1379 ━━━━━━━━━━━━━━━━━━━━ 0s 904ms/step - acc: 0.9530 - auc: 0.9354 - loss: 0.3543 - top3: 0.9989
# Epoch 19: val_acc did not improve from 0.90332
# 1379/1379 ━━━━━━━━━━━━━━━━━━━━ 1291s 935ms/step - acc: 0.9530 - auc: 0.9354 - loss: 0.3543 - top3: 0.9989 - val_acc: 0.9005 - val_auc: 0.9864 - val_loss: 0.4241 - val_top3: 0.9793
# Epoch 20/30
# 1379/1379 ━━━━━━━━━━━━━━━━━━━━ 0s 914ms/step - acc: 0.9526 - auc: 0.9348 - loss: 0.3543 - top3: 0.9995
# Epoch 20: val_acc did not improve from 0.90332
# 1379/1379 ━━━━━━━━━━━━━━━━━━━━ 1304s 944ms/step - acc: 0.9526 - auc: 0.9348 - loss: 0.3543 - top3: 0.9995 - val_acc: 0.9006 - val_auc: 0.9870 - val_loss: 0.4224 - val_top3: 0.9799
# Epoch 21/30
# 1379/1379 ━━━━━━━━━━━━━━━━━━━━ 0s 909ms/step - acc: 0.9556 - auc: 0.9363 - loss: 0.3545 - top3: 0.9991
# Epoch 21: val_acc did not improve from 0.90332
# 1379/1379 ━━━━━━━━━━━━━━━━━━━━ 1297s 939ms/step - acc: 0.9556 - auc: 0.9363 - loss: 0.3545 - top3: 0.9991 - val_acc: 0.9006 - val_auc: 0.9876 - val_loss: 0.4214 - val_top3: 0.9808
# Epoch 22/30
# 1379/1379 ━━━━━━━━━━━━━━━━━━━━ 0s 909ms/step - acc: 0.9562 - auc: 0.9353 - loss: 0.3551 - top3: 0.9987
# Epoch 22: val_acc did not improve from 0.90332
# 1379/1379 ━━━━━━━━━━━━━━━━━━━━ 1297s 939ms/step - acc: 0.9562 - auc: 0.9353 - loss: 0.3551 - top3: 0.9987 - val_acc: 0.9007 - val_auc: 0.9882 - val_loss: 0.4204 - val_top3: 0.9817
# Epoch 23/30
# 1379/1379 ━━━━━━━━━━━━━━━━━━━━ 0s 923ms/step - acc: 0.9557 - auc: 0.9357 - loss: 0.3543 - top3: 0.9992
# Epoch 23: val_acc did not improve from 0.90332
# 1379/1379 ━━━━━━━━━━━━━━━━━━━━ 1316s 953ms/step - acc: 0.9557 - auc: 0.9357 - loss: 0.3543 - top3: 0.9992 - val_acc: 0.9010 - val_auc: 0.9882 - val_loss: 0.4193 - val_top3: 0.9816
# Epoch 24/30
# 1379/1379 ━━━━━━━━━━━━━━━━━━━━ 0s 910ms/step - acc: 0.9551 - auc: 0.9358 - loss: 0.3545 - top3: 0.9990
# Epoch 24: val_acc did not improve from 0.90332
# 1379/1379 ━━━━━━━━━━━━━━━━━━━━ 1299s 941ms/step - acc: 0.9551 - auc: 0.9358 - loss: 0.3545 - top3: 0.9990 - val_acc: 0.9012 - val_auc: 0.9869 - val_loss: 0.4209 - val_top3: 0.9803
# Epoch 25/30
# 1379/1379 ━━━━━━━━━━━━━━━━━━━━ 0s 918ms/step - acc: 0.9556 - auc: 0.9371 - loss: 0.3527 - top3: 0.9992
# Epoch 25: val_acc did not improve from 0.90332
# 1379/1379 ━━━━━━━━━━━━━━━━━━━━ 1350s 978ms/step - acc: 0.9556 - auc: 0.9371 - loss: 0.3527 - top3: 0.9992 - val_acc: 0.9017 - val_auc: 0.9871 - val_loss: 0.4201 - val_top3: 0.9807
# Epoch 26/30
# 1379/1379 ━━━━━━━━━━━━━━━━━━━━ 0s 921ms/step - acc: 0.9547 - auc: 0.9363 - loss: 0.3527 - top3: 0.9993
# Epoch 26: val_acc did not improve from 0.90332
# 1379/1379 ━━━━━━━━━━━━━━━━━━━━ 1365s 951ms/step - acc: 0.9547 - auc: 0.9363 - loss: 0.3527 - top3: 0.9993 - val_acc: 0.9020 - val_auc: 0.9874 - val_loss: 0.4192 - val_top3: 0.9817
# Epoch 27/30
# 1379/1379 ━━━━━━━━━━━━━━━━━━━━ 0s 917ms/step - acc: 0.9566 - auc: 0.9366 - loss: 0.3529 - top3: 0.9990
# Epoch 27: val_acc did not improve from 0.90332
# 1379/1379 ━━━━━━━━━━━━━━━━━━━━ 1338s 948ms/step - acc: 0.9566 - auc: 0.9366 - loss: 0.3529 - top3: 0.9990 - val_acc: 0.9015 - val_auc: 0.9874 - val_loss: 0.4184 - val_top3: 0.9811
# Epoch 28/30
# 1379/1379 ━━━━━━━━━━━━━━━━━━━━ 0s 919ms/step - acc: 0.9548 - auc: 0.9371 - loss: 0.3514 - top3: 0.9989
# Epoch 28: val_acc did not improve from 0.90332
# 1379/1379 ━━━━━━━━━━━━━━━━━━━━ 1343s 949ms/step - acc: 0.9548 - auc: 0.9371 - loss: 0.3514 - top3: 0.9989 - val_acc: 0.9016 - val_auc: 0.9868 - val_loss: 0.4192 - val_top3: 0.9795
# Epoch 29/30
# 1379/1379 ━━━━━━━━━━━━━━━━━━━━ 0s 918ms/step - acc: 0.9565 - auc: 0.9363 - loss: 0.3522 - top3: 0.9993
# Epoch 29: val_acc did not improve from 0.90332
# 1379/1379 ━━━━━━━━━━━━━━━━━━━━ 1310s 949ms/step - acc: 0.9565 - auc: 0.9363 - loss: 0.3522 - top3: 0.9993 - val_acc: 0.9017 - val_auc: 0.9869 - val_loss: 0.4199 - val_top3: 0.9810
# Epoch 30/30
# 1379/1379 ━━━━━━━━━━━━━━━━━━━━ 0s 922ms/step - acc: 0.9573 - auc: 0.9354 - loss: 0.3530 - top3: 0.9991
# Epoch 30: val_acc did not improve from 0.90332
# 1379/1379 ━━━━━━━━━━━━━━━━━━━━ 1315s 952ms/step - acc: 0.9574 - auc: 0.9354 - loss: 0.3530 - top3: 0.9991 - val_acc: 0.9018 - val_auc: 0.9870 - val_loss: 0.4199 - val_top3: 0.9804
# Restoring model weights from the end of the best epoch: 27.
# E0000 00:00:1754251361.620282     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754251361.828335     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754251362.099090     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754251362.250726     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754251362.775109     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754251362.966370     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754251363.358475     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754251363.521937     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754251363.961039     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754251364.121152     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754251364.492023     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754251364.645701     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754251365.272381     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754251365.424442     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754251365.756707     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754251365.908704     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754251366.733016     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754251366.894219     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754251367.259246     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754251367.411556     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754251367.723592     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754251367.884940     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754251368.209195     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754251368.361735     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754251368.700417     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754251368.852969     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754251369.717837     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754251369.880145     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754251370.311101     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754251370.464821     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754251370.649303     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754251370.811933     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754251371.247174     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754251371.409507     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754251371.843402     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754251371.993620     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754251372.174586     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754251372.337178     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754251372.622252     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754251372.772538     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754251373.093103     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754251373.255689     215 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
#      loss : 0.3265
# compile_metrics : 0.9294
#
# Overall Test Metrics
# ====================
# Test Accuracy : 0.9369
# Top-3 Accuracy: 0.9915
# Test AUC      : 0.9958
# Macro-F1      : 0.9254
#
# Classification Report
# ====================
#                 precision    recall  f1-score   support
#
#      Alveolina     0.9340    0.9912    0.9618      5129
#       Arumella     0.9985    0.9431    0.9700      2163
# Ataxophragmium     0.9926    0.9857    0.9891      4898
#  Baculogypsina     0.9748    0.4413    0.6075      2980
#   Chrysalidina     0.9104    0.9922    0.9495      5111
#    Coskinolina     0.9545    0.9324    0.9433      5060
#    Elphidiella     0.9317    0.9947    0.9621      3385
#       Fallotia     0.9984    0.9994    0.9989      5009
#     Lockhartia     0.9781    0.9994    0.9886      5359
#        Minoxia     0.9685    0.9592    0.9638      3557
#     Orbitoides     0.7393    0.8973    0.8107      5015
#   Rhapydionina     0.9949    0.9269    0.9597      3802
#
#       accuracy                         0.9369     51468
#      macro avg     0.9480    0.9219    0.9254     51468
#   weighted avg     0.9429    0.9369    0.9329     51468
# ✅ All done - outputs saved in: results_stronger_regularization_v11_segmented_o3/nasnet
# CPU times: user 18h 10min 20s, sys: 1h 18min 19s, total: 19h 28min 39s
# Wall time: 12h 23min 58s
